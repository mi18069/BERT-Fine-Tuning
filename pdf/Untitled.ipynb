# %%
from transformers import DistilBertTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("classla/bcms-bertic")

# %%
sentence = "Ovo je primer koji ilustruje rad tokenizatora"

# %%
tokens = tokenizer.tokenize(sennce

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 sentence = "Ovo je primer za tokenizaciju."
# ----> 2 encoding = tokenizer(sentence, return_tensors="pt")
#       3 tokens = tokenizer.tokenize(sentence)
#       4 token_ids = tokenizer.convert_tokens_to_ids(tokens)
#
# File ~/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2860, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2858     if not self._in_target_context_manager:
#    2859         self._switch_to_input_mode()
# ...

# %%
from transformers import AutoTokenizer

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("classla/bcms-bertic")

# Tokenize a sample Serbian sentence
sentence = "Ovo je primer za tokenizaciju."
encoding = tokenizer(sentence, return_tensors="pt")
tokens = tokenizer.convert_ids_to_tokens(encoding["input_ids"][0])
token_ids = encoding["input_ids"][0].tolist()

print("BERTić Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [26], in <cell line: 8>()
#       6 # Tokenize a sample Serbian sentence
#       7 sentence = "Ovo je primer za tokenizaciju."
# ----> 8 encoding = tokenizer(sentence, return_tensors="pt")
#       9 tokens = tokenizer.convert_ids_to_tokens(encoding["input_ids"][0])
#      10 token_ids = encoding["input_ids"][0].tolist()
#
# File ~/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2860, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
# ...

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 import torch
#
# File ~/.local/lib/python3.10/site-packages/torch/__init__.py:415, in <module>
#     404 else:
#     405     # Easy way.  You want this most of the time, because it will prevent
#     406     # C++ symbols from libtorch clobbering C++ symbols from other
#    (...)
#     412     #
#     413     # See Note [Global dependencies]
#     414     if USE_GLOBAL_DEPS:
# --> 415         _load_global_deps()
#     416     from torch._C import *  # noqa: F403
#     419 class SymInt:
#
# File ~/.local/lib/python3.10/site-packages/torch/__init__.py:371, in _load_global_deps()
#     367 is_cuda_lib_err = [
#     368     lib for lib in cuda_libs.values() if lib.split(".")[0] in err.args[0]
#     369 ]
#     370 if not is_cuda_lib_err:
# --> 371     raise err
# ...
